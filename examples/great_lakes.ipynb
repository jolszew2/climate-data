# %%
import sys
sys.path.append('..')
import climate_data.copernicus.cmip6 as cmip6
import climate_data.copernicus.request as cds
from climate_data.countries import get_country_bounding_box

# %% [markdown]
# ## Define area of interest

# %%
greatlakes_BBOX = (51, -93, 40, -70)
print(greatlakes_BBOX)
# Out:
# (51, -93, 40, -70)

# %% [markdown]
# ## Use CMIP6Request() function to request data for a single model, experiment, and location combo

# %%
small_request = cds.CMIP6Request(years=cmip6.HISTORY_YEARS[0:2], variable=cmip6.Variables.TEMP, location=greatlakes_BBOX)

# %% [markdown]
# ## Use CMIP6Experiment() function to request data across multiple models for a single experiment and location combo

# %%
big_request = cds.CMIP6Experiment(experiment=cmip6.Experiments.HISTORICAL, location=greatlakes_BBOX)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 big_request = cds.CMIP6Experiment(experiment=cmip6.Experiments.HISTORICAL, location=greatlakes_BBOX)
#
# TypeError: CMIP6Experiment.__init__() got an unexpected keyword argument 'location'

# %% [markdown]
# ## Download requests

# %%
dirbase = 'C:/Users/jolszewski/OneDrive - DOI/GLCRS/data/copernicus/'
small_request.download(directory=small_request.create_directories(dirbase), overwrite=True)
# Out:
# 2025-01-31 16:59:30,902 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-01-31 16:59:30,903 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2025-01-31 16:59:31,744 INFO Request ID is 23e74490-e878-4717-8b5c-6e048d92397f
# 2025-01-31 16:59:31,910 INFO status has been updated to accepted
# 2025-01-31 16:59:40,739 INFO status has been updated to running
# 2025-01-31 16:59:45,970 INFO status has been updated to successful
# 'C:\\Users\\jolszewski\\OneDrive - DOI\\GLCRS\\data\\copernicus\\cmip6\\tas\\monthly\\access_cm2_historical_185001-185112.nc'

# %%
small_requests = cds.build_CMIP6Requests(location=greatlakes_BBOX,
                                         variables=[cmip6.Variables.TEMP],
                                         timesteps=[cmip6.TemporalResolutions.MONTHLY],
                                         models=[cmip6.Models.ACCESS_CM2],
                                         experiments=[cmip6.Experiments.HISTORICAL])
cds.download_requests(small_requests, dirbase, overwrite=True)
# Out:
# ...
# 2025-01-31 17:00:47,995 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-01-31 17:00:47,996 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2025-01-31 17:00:49,000 INFO Request ID is bacd4215-2fc7-4812-b941-ad5ca41ec432
# 2025-01-31 17:00:49,150 INFO status has been updated to accepted
# 2025-01-31 17:00:58,018 INFO status has been updated to running
# 2025-01-31 17:01:03,232 INFO status has been updated to accepted
# 2025-01-31 17:01:10,971 INFO status has been updated to successful
#     [0] Status.SUCCESS: access_cm2_historical_185001-201412.nc
# Successfully processed 1 of 1 requests.
